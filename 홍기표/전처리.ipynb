# %%
import sys

sys.path.append(
    r"C:\Users\Playdata\Documents\Codex\2026-09-14\c-users-playdata-desktop-enkoa-practice\outputs"
)

from preprocess_recipes_only import preprocess_jsonl

stats = preprocess_jsonl(
    input_path=r"C:\Users\Playdata\Desktop\mle-01-p2-team2\홍기표\input\recipes_10000.jsonl",
    output_path=r"C:\Users\Playdata\Desktop\mle-01-p2-team2\전처리\recipes_10000_preprocessed.jsonl",
    review_path=r"C:\Users\Playdata\Desktop\mle-01-p2-team2\전처리\recipes_10000_review.jsonl",
    error_path=r"C:\Users\Playdata\Desktop\mle-01-p2-team2\전처리\recipes_10000_errors.jsonl",
)

stats

# %%
import sys
from pathlib import Path

# 전처리 코드 파일 위치
script_dir = Path(
    r"C:\Users\Playdata\Documents\Codex\2026-09-14"
    r"\c-users-playdata-desktop-enkoa-practice\outputs"
)

# 원본·결과 파일 위치
input_path = Path(
    r"C:\Users\Playdata\Desktop\mle-01-p2-team2\홍기표\input\recipes_10000.jsonl"
)

output_path = Path(
    r"C:\Users\Playdata\Desktop\mle-01-p2-team2\전처리"
    r"\recipes_10000_preprocessed.jsonl"
)

review_path = Path(
    r"C:\Users\Playdata\Desktop\mle-01-p2-team2\전처리"
    r"\recipes_10000_review.jsonl"
)

error_path = Path(
    r"C:\Users\Playdata\Desktop\mle-01-p2-team2\전처리"
    r"\recipes_10000_errors.jsonl"
)

# 파일 경로 확인
assert script_dir.exists(), f"전처리 코드 폴더가 없습니다: {script_dir}"
assert input_path.exists(), f"원본 파일이 없습니다: {input_path}"

# 전처리 코드 불러오기
sys.path.insert(0, str(script_dir))

from preprocess_recipes_only import preprocess_jsonl

# 결과 폴더 생성
output_path.parent.mkdir(parents=True, exist_ok=True)

# 전처리 실행
stats = preprocess_jsonl(
    input_path=input_path,
    output_path=output_path,
    review_path=review_path,
    error_path=error_path,
)

print(stats)
# Out:
# {'read': 10000, 'written': 10000, 'blank': 0, 'json_errors': 0, 'record_errors': 0, 'review_rows': 17903}

# %%
{
    "recipe_uid": "10000recipe:6915088",
    "source": "10000recipe",
    "source_id": "6915088",
    "source_url": "https://www.10000recipe.com/recipe/6915088",
    "title": "밥도둑 반찬 고추장 달걀조림 만들기!TV 알토란 레시피",
    "description": "평소 간장을 베이스로 한 계란장조림을 만들어 먹는 편인데요. TV알토란에서 고추장을 베이스로 계란 장조림을 만들길래 저도 만들어 봤는데 우왕! 진짜 맛있어요. 뜨끈한 밥에 비벼 먹으니 밥도둑이 따로 없네요^^",
    "servings": {
        "raw": "3인분",
        "type": "exact",
        "value": 3.0,
        "min": 3.0,
        "max": 3.0,
        "unit_raw": "인분",
        "unit": "인분",
        "note": null,
        "qualitative": null,
        "parse_status": "ok",
        "secondary_amounts": [],
    },
    "cooking_time": {
        "raw": "20분 이내",
        "type": "upper_bound",
        "value": 20.0,
        "min": null,
        "max": 20.0,
        "unit_raw": "분",
        "unit": "분",
        "note": "이내",
        "qualitative": null,
        "parse_status": "ok",
        "secondary_amounts": [],
    },
    "difficulty": "아무나",
    "views": 353000,
    "selection_reason": "top_views",
    "components": [
        {
            "index": 0,
            "role": "ingredient",
            "group": "[재료]",
            "name_raw": "달걀",
            "name_normalized": "계란",
            "base_name": "계란",
            "preparation": null,
            "detail": null,
            "alternative_options": [],
            "amount_raw": "10개",
            "amount_source": "amount_field",
            "quantity": {
                "raw": "10개",
                "type": "exact",
                "value": 10.0,
                "min": 10.0,
                "max": 10.0,
                "unit_raw": "개",
                "unit": "개",
                "note": null,
                "qualitative": null,
                "parse_status": "ok",
                "secondary_amounts": [],
            },
            "raw": "달걀 10개",
            "quality_flags": [],
        },
        {
            "index": 1,
            "role": "ingredient",
            "group": "[재료]",
            "name_raw": "양파",
            "name_normalized": "양파",
            "base_name": "양파",
            "preparation": null,
            "detail": null,
            "alternative_options": [],
            "amount_raw": "1개",
            "amount_source": "amount_field",
            "quantity": {
                "raw": "1개",
                "type": "exact",
                "value": 1.0,
                "min": 1.0,
                "max": 1.0,
                "unit_raw": "개",
                "unit": "개",
                "note": null,
                "qualitative": null,
                "parse_status": "ok",
                "secondary_amounts": [],
            },
            "raw": "양파 1개",
            "quality_flags": [],
        },
        {
            "index": 2,
            "role": "ingredient",
            "group": "[재료]",
            "name_raw": "청양고추",
            "name_normalized": "청양고추",
            "base_name": "청양고추",
            "preparation": null,
            "detail": null,
            "alternative_options": [],
            "amount_raw": "3개",
            "amount_source": "amount_field",
            "quantity": {
                "raw": "3개",
                "type": "exact",
                "value": 3.0,
                "min": 3.0,
                "max": 3.0,
                "unit_raw": "개",
                "unit": "개",
                "note": null,
                "qualitative": null,
                "parse_status": "ok",
                "secondary_amounts": [],
            },
            "raw": "청양고추 3개",
            "quality_flags": [],
        },
        {
            "index": 3,
            "role": "ingredient",
            "group": "[재료]",
            "name_raw": "쪽파 또는 대파",
            "name_normalized": "쪽파",
            "base_name": "쪽파",
            "preparation": null,
            "detail": null,
            "alternative_options": ["쪽파", "대파"],
            "amount_raw": "또는 대파",
            "amount_source": "raw_field",
            "quantity": {
                "raw": "약간",
                "type": "qualitative",
                "value": null,
                "min": null,
                "max": null,
                "unit_raw": null,
                "unit": null,
                "note": null,
                "qualitative": "약간",
                "parse_status": "ok",
                "secondary_amounts": [],
            },
            "raw": "쪽파 또는 대파 약간",
            "quality_flags": ["alternative_present", "amount_derived_from_raw"],
        },
        {
            "index": 4,
            "role": "ingredient",
            "group": "[재료]",
            "name_raw": "멸치육수",
            "name_normalized": "멸치육수",
            "base_name": "멸치육수",
            "preparation": null,
            "detail": null,
            "alternative_options": [],
            "amount_raw": "1.5컵",
            "amount_source": "amount_field",
            "quantity": {
                "raw": "1.5컵",
                "type": "exact",
                "value": 1.5,
                "min": 1.5,
                "max": 1.5,
                "unit_raw": "컵",
                "unit": "컵",
                "note": null,
                "qualitative": null,
                "parse_status": "ok",
                "secondary_amounts": [],
            },
            "raw": "멸치육수 1.5컵",
            "quality_flags": [],
        },
        {
            "index": 5,
            "role": "seasoning",
            "group": "[양념]",
            "name_raw": "고추장",
            "name_normalized": "고추장",
            "base_name": "고추장",
            "preparation": null,
            "detail": null,
            "alternative_options": [],
            "amount_raw": "2T",
            "amount_source": "amount_field",
            "quantity": {
                "raw": "2T",
                "type": "exact",
                "value": 2.0,
                "min": 2.0,
                "max": 2.0,
                "unit_raw": "T",
                "unit": "큰술",
                "note": null,
                "qualitative": null,
                "parse_status": "ok",
                "secondary_amounts": [],
            },
            "raw": "고추장 2T",
            "quality_flags": [],
        },
        {
            "index": 6,
            "role": "seasoning",
            "group": "[양념]",
            "name_raw": "고춧가루",
            "name_normalized": "고춧가루",
            "base_name": "고춧가루",
            "preparation": null,
            "detail": null,
            "alternative_options": [],
            "amount_raw": "3T",
            "amount_source": "amount_field",
            "quantity": {
                "raw": "3T",
                "type": "exact",
                "value": 3.0,
                "min": 3.0,
                "max": 3.0,
                "unit_raw": "T",
                "unit": "큰술",
                "note": null,
                "qualitative": null,
                "parse_status": "ok",
                "secondary_amounts": [],
            },
            "raw": "고춧가루 3T",
            "quality_flags": [],
        },
        {
            "index": 7,
            "role": "seasoning",
            "group": "[양념]",
            "name_raw": "진간장",
            "name_normalized": "진간장",
            "base_name": "진간장",
            "preparation": null,
            "detail": null,
            "alternative_options": [],
            "amount_raw": "4T",
            "amount_source": "amount_field",
            "quantity": {
                "raw": "4T",
                "type": "exact",
                "value": 4.0,
                "min": 4.0,
                "max": 4.0,
                "unit_raw": "T",
                "unit": "큰술",
                "note": null,
                "qualitative": null,
                "parse_status": "ok",
                "secondary_amounts": [],
            },
            "raw": "진간장 4T",
            "quality_flags": [],
        },
        {
            "index": 8,
            "role": "seasoning",
            "group": "[양념]",
            "name_raw": "설탕",
            "name_normalized": "설탕",
            "base_name": "설탕",
            "preparation": null,
            "detail": null,
            "alternative_options": [],
            "amount_raw": "2T",
            "amount_source": "amount_field",
            "quantity": {
                "raw": "2T",
                "type": "exact",
                "value": 2.0,
                "min": 2.0,
                "max": 2.0,
                "unit_raw": "T",
                "unit": "큰술",
                "note": null,
                "qualitative": null,
                "parse_status": "ok",
                "secondary_amounts": [],
            },
            "raw": "설탕 2T",
            "quality_flags": [],
        },
        {
            "index": 9,
            "role": "seasoning",
            "group": "[양념]",
            "name_raw": "물엿",
            "name_normalized": "물엿",
            "base_name": "물엿",
            "preparation": null,
            "detail": null,
            "alternative_options": [],
            "amount_raw": "3T",
            "amount_source": "amount_field",
            "quantity": {
                "raw": "3T",
                "type": "exact",
                "value": 3.0,
                "min": 3.0,
                "max": 3.0,
                "unit_raw": "T",
                "unit": "큰술",
                "note": null,
                "qualitative": null,
                "parse_status": "ok",
                "secondary_amounts": [],
            },
            "raw": "물엿 3T",
            "quality_flags": [],
        },
        {
            "index": 10,
            "role": "seasoning",
            "group": "[양념]",
            "name_raw": "참기름",
            "name_normalized": "참기름",
            "base_name": "참기름",
            "preparation": null,
            "detail": null,
            "alternative_options": [],
            "amount_raw": "2T",
            "amount_source": "amount_field",
            "quantity": {
                "raw": "2T",
                "type": "exact",
                "value": 2.0,
                "min": 2.0,
                "max": 2.0,
                "unit_raw": "T",
                "unit": "큰술",
                "note": null,
                "qualitative": null,
                "parse_status": "ok",
                "secondary_amounts": [],
            },
            "raw": "참기름 2T",
            "quality_flags": [],
        },
        {
            "index": 11,
            "role": "seasoning",
            "group": "[양념]",
            "name_raw": "깨",
            "name_normalized": "깨",
            "base_name": "깨",
            "preparation": null,
            "detail": null,
            "alternative_options": [],
            "amount_raw": "1T",
            "amount_source": "amount_field",
            "quantity": {
                "raw": "1T",
                "type": "exact",
                "value": 1.0,
                "min": 1.0,
                "max": 1.0,
                "unit_raw": "T",
                "unit": "큰술",
                "note": null,
                "qualitative": null,
                "parse_status": "ok",
                "secondary_amounts": [],
            },
            "raw": "깨 1T",
            "quality_flags": [],
        },
        {
            "index": 12,
            "role": "seasoning",
            "group": "[양념]",
            "name_raw": "후추",
            "name_normalized": "후추",
            "base_name": "후추",
            "preparation": null,
            "detail": null,
            "alternative_options": [],
            "amount_raw": "1ts",
            "amount_source": "amount_field",
            "quantity": {
                "raw": "1ts",
                "type": "exact",
                "value": 1.0,
                "min": 1.0,
                "max": 1.0,
                "unit_raw": "t",
                "unit": "작은술",
                "note": "s",
                "qualitative": null,
                "parse_status": "ok",
                "secondary_amounts": [],
            },
            "raw": "후추 1ts",
            "quality_flags": [],
        },
    ],
    "tools": [],
    "steps": [
        {
            "order": 1,
            "text": "먼저 물에 소금1T,식초1T를 섞어 달걀을 7-8분 반숙으로 삶아 줍니다.",
        },
        {
            "order": 2,
            "text": "달걀이 삶아지는 동안 양파는 굵게 채 썰고 청양고추도 큼직큼직 썰어주셔요",
        },
        {
            "order": 3,
            "text": "달걀이 삶아지면 얼음물에 바로 행궈 껍질을 깔끔히 잘 벗겨 줍니다.",
        },
        {
            "order": 4,
            "text": "참기름과 깨를 제외한 모든 양념을 한곳에 미리 섞어주셔요. 평소 단 것 싫으시면 설탕, 물엿은 조금 줄이셔도 됩니다",
        },
        {
            "order": 5,
            "text": "냄비에 멸치육수를 넣고 양념을 잘 풀어 주신뒤 끓여줍니다.",
        },
        {"order": 6, "text": "양념이 끓기 시작하면 양파와 청양고추를 넣고 끓여줍니다."},
        {
            "order": 7,
            "text": "양념이 반정도 졸아들었다 싶을때 반숙달걀을 투하 해줍니다.이대로 약 2분정도 더 끓여주시면서 달걀에 색이 입혀지게 국물을 끼얹어 주세요",
        },
        {
            "order": 8,
            "text": "마지막으로 참기름 2T와 깨1T를 넣고 잘섞어주시고 쪽파를 고명으로 올려주시면 끝!",
        },
        {
            "order": 9,
            "text": "밥도둑 반찬 알토란 임성근님의 고추장 달걀조림 완성입니다^^",
        },
        {
            "order": 10,
            "text": "한번 먹어보니 촉촉한 반숙달걀에 매콤달콤 양념이 어우려져 넘 맛있네요.꼭 떡볶이 양념같은게 은근 중독성 있고 정말 짱짱짱!뜨끈한 밥에 비벼 먹으면 밥 한공기 뚝딱 하게 됩니다^^",
        },
    ],
    "quality_flags": ["component_review_exists"],
}

# %%
{
    "recipe_uid": "10000recipe:6867256",
    "source_id": "6867256",
    "recipe_title": "백종원레시피로 만든 콩나물무침으로 밥 한 끼 뚝딱 ~",
    "component_index": 1,
    "role": "ingredient",
    "name_raw": "대파 또는 쪽파",
    "amount_raw": "또는 쪽파",
    "quantity_raw": "1/6대",
    "raw": "대파 또는 쪽파 1/6대",
    "review_reasons": ["alternative_present", "amount_derived_from_raw"],
}
